# %%
import scanpy as sc
from subtype_analysis import *

# %%
dataset = "Xenium_Prime_Ovarian_Cancer_FFPE"
ad = sc.read_h5ad("E:/SZ/Results/" + dataset + "/" + dataset + "_GWT_anndata.h5ad")

# use cell type labels from the original dataset
if dataset == "Xenium_Prime_Ovarian_Cancer_FFPE":
    celltype = pd.read_csv("E:/SZ/Results/" + dataset + "/Xenium_Prime_Ovarian_Cancer_FFPE_cell_groups.csv")
    obs_df = ad.obs.copy()
    merged_df = obs_df.merge(celltype[['cell_id', 'group']], on='cell_id', how='left')
    ad.obs = merged_df

    ad.obs['Cell_Type'] = ad.obs['group']
ad
# Out:
# AnnData object with n_obs × n_vars = 397855 × 5099
#     obs: 'cell_id', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'region', 'z_level', 'cell_labels', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_10_genes', 'pct_counts_in_top_20_genes', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_150_genes', 'n_counts', 'n_genes', 'Kmeans_Raw', 'leiden_Raw_res0.4', 'leiden_Raw_res0.6', 'leiden_Raw_res0.8', 'leiden_Raw_res1', 'leiden_Raw_res1.2', 'Kmeans_scale0.01', 'leiden_scale0.01_res0.4', 'leiden_scale0.01_res0.6', 'leiden_scale0.01_res0.8', 'leiden_scale0.01_res1', 'leiden_scale0.01_res1.2', 'Kmeans_scale0.6', 'leiden_scale0.6_res0.4', 'leiden_scale0.6_res0.6', 'leiden_scale0.6_res0.8', 'leiden_scale0.6_res1', 'leiden_scale0.6_res1.2', 'Kmeans_scale1.2', 'leiden_scale1.2_res0.4', 'leiden_scale1.2_res0.6', 'leiden_scale1.2_res0.8', 'leiden_scale1.2_res1', 'leiden_scale1.2_res1.2', 'Kmeans_scale1.6', 'leiden_scale1.6_res0.4', 'leiden_scale1.6_res0.6', 'leiden_scale1.6_res0.8', 'leiden_scale1.6_res1', 'leiden_scale1.6_res1.2', 'Kmeans_scale3.0', 'leiden_scale3.0_res0.4', 'leiden_scale3.0_res0.6', 'leiden_scale3.0_res0.8', 'leiden_scale3.0_res1', 'leiden_scale3.0_res1.2', 'Kmeans_scale4.0', 'leiden_scale4.0_res0.4', 'leiden_scale4.0_res0.6', 'leiden_scale4.0_res0.8', 'leiden_scale4.0_res1', 'leiden_scale4.0_res1.2', 'Kmeans_scale5.0', 'leiden_scale5.0_res0.4', 'leiden_scale5.0_res0.6', 'leiden_scale5.0_res0.8', 'leiden_scale5.0_res1', 'leiden_scale5.0_res1.2', 'Kmeans_scale6.5', 'leiden_scale6.5_res0.4', 'leiden_scale6.5_res0.6', 'leiden_scale6.5_res0.8', 'leiden_scale6.5_res1', 'leiden_scale6.5_res1.2', 'Kmeans_scale8.5', 'leiden_scale8.5_res0.4', 'leiden_scale8.5_res0.6', 'leiden_scale8.5_res0.8', 'leiden_scale8.5_res1', 'leiden_scale8.5_res1.2', 'Kmeans_scale13.0', 'leiden_scale13.0_res0.4', 'leiden_scale13.0_res0.6', 'leiden_scale13.0_res0.8', 'leiden_scale13.0_res1', 'leiden_scale13.0_res1.2', 'Kmeans_scale25.0', 'leiden_scale25.0_res0.4', 'leiden_scale25.0_res0.6', 'leiden_scale25.0_res0.8', 'leiden_scale25.0_res1', 'leiden_scale25.0_res1.2', 'Kmeans_scale40.0', 'leiden_scale40.0_res0.4', 'leiden_scale40.0_res0.6', 'leiden_scale40.0_res0.8', 'leiden_scale40.0_res1', 'leiden_scale40.0_res1.2', 'group', 'Cell_Type'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells'
#     uns: 'leiden_Raw_res0.4_colors', 'leiden_Raw_res0.6_colors', 'leiden_Raw_res0.8_colors', 'leiden_Raw_res1.2_colors', 'leiden_Raw_res1_colors', 'leiden_scale0.01_res0.4_colors', 'leiden_scale0.01_res0.6_colors', 'leiden_scale0.01_res0.8_colors', 'leiden_scale0.01_res1.2_colors', 'leiden_scale0.01_res1_colors', 'leiden_scale0.6_res0.4_colors', 'leiden_scale0.6_res0.6_colors', 'leiden_scale0.6_res0.8_colors', 'leiden_scale0.6_res1.2_colors', 'leiden_scale0.6_res1_colors', 'leiden_scale1.2_res0.4_colors', 'leiden_scale1.2_res0.6_colors', 'leiden_scale1.2_res0.8_colors', 'leiden_scale1.2_res1.2_colors', 'leiden_scale1.2_res1_colors', 'leiden_scale1.6_res0.4_colors', 'leiden_scale1.6_res0.6_colors', 'leiden_scale1.6_res0.8_colors', 'leiden_scale1.6_res1.2_colors', 'leiden_scale1.6_res1_colors', 'leiden_scale13.0_res0.4_colors', 'leiden_scale13.0_res0.6_colors', 'leiden_scale13.0_res0.8_colors', 'leiden_scale13.0_res1.2_colors', 'leiden_scale13.0_res1_colors', 'leiden_scale25.0_res0.4_colors', 'leiden_scale25.0_res0.6_colors', 'leiden_scale25.0_res0.8_colors', 'leiden_scale25.0_res1.2_colors', 'leiden_scale25.0_res1_colors', 'leiden_scale3.0_res0.4_colors', 'leiden_scale3.0_res0.6_colors', 'leiden_scale3.0_res0.8_colors', 'leiden_scale3.0_res1.2_colors', 'leiden_scale3.0_res1_colors', 'leiden_scale4.0_res0.4_colors', 'leiden_scale4.0_res0.6_colors', 'leiden_scale4.0_res0.8_colors', 'leiden_scale4.0_res1.2_colors', 'leiden_scale4.0_res1_colors', 'leiden_scale40.0_res0.4_colors', 'leiden_scale40.0_res0.6_colors', 'leiden_scale40.0_res0.8_colors', 'leiden_scale40.0_res1.2_colors', 'leiden_scale40.0_res1_colors', 'leiden_scale5.0_res0.4_colors', 'leiden_scale5.0_res0.6_colors', 'leiden_scale5.0_res0.8_colors', 'leiden_scale5.0_res1.2_colors', 'leiden_scale5.0_res1_colors', 'leiden_scale6.5_res0.4_colors', 'leiden_scale6.5_res0.6_colors', 'leiden_scale6.5_res0.8_colors', 'leiden_scale6.5_res1.2_colors', 'leiden_scale6.5_res1_colors', 'leiden_scale8.5_res0.4_colors', 'leiden_scale8.5_res0.6_colors', 'leiden_scale8.5_res0.8_colors', 'leiden_scale8.5_res1.2_colors', 'leiden_scale8.5_res1_colors', 'log1p', 'spatialdata_attrs'
#     obsm: 'X_nmf', 'X_umap_Raw', 'X_umap_scale0.01', 'X_umap_scale0.6', 'X_umap_scale1.2', 'X_umap_scale1.6', 'X_umap_scale13.0', 'X_umap_scale25.0', 'X_umap_scale3.0', 'X_umap_scale4.0', 'X_umap_scale40.0', 'X_umap_scale5.0', 'X_umap_scale6.5', 'X_umap_scale8.5', 'spatial'
#     varm: 'nmf_loadings'
#     layers: 'counts'
#     obsp: 'expr_knn', 'spatial_knn'

# %%
save_path = "./results/" + dataset + "/"
cluster_key = 'Cell_Type'
umap_keys, var_dict, k_dict, selected_cluster_recommend = calculate_metrics(ad=ad, save_path=save_path, cluster_key=cluster_key)
# Out:
# c:\Users\fyh\miniconda3\envs\pycogaps\lib\site-packages\scanpy\plotting\_tools\scatterplots.py:1154: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter([], [], c=palette[label], label=label)

# %%
# selected_cluster = selected_cluster_recommend
selected_cluster = "Tumor Associated Fibroblasts"    # define the cluster you want to analyze here

ad_selected = ad[ad.obs[cluster_key] == selected_cluster]
kde_plot(ad_selected=ad_selected, save_path=save_path)

# %%
optimal_scale = find_optimal_scale(var_dict[selected_cluster], umap_keys=umap_keys)
print("optimal_scale: ", optimal_scale)
# Out:
# optimal_scale:  6.5

# %%
# optimal_scale = 4.5 # manually set the optimal scale here
ad_selected_plot, ward_list = detect_subclusters(ad_selected=ad_selected, save_path=save_path, optimal_scale=optimal_scale)
# Out:
# c:\Projects\spatialzoomer\code\subtype_analysis.py:209: ImplicitModificationWarning: Setting element `.obsm['X_umap']` of view, initializing view as actual.
#   ad_selected.obsm['X_umap'] = ad_selected.obsm['X_umap_scale' + str(optimal_scale)]
# c:\Users\fyh\miniconda3\envs\pycogaps\lib\site-packages\anndata\_core\aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# c:\Projects\spatialzoomer\code\subtype_analysis.py:215: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   ad_selected_plot.uns['cluster_label_colors'] = [colors_3[1], colors_3[0]]
